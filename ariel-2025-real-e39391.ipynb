# %%
#https://www.kaggle.com/code/vitalykudelya/neurips-non-ml-transit-curve-fitting?scriptVersionId=250312271
import pandas as pd
import numpy as np
import torch
import torch.nn.functional as F
import multiprocessing as mp
from tqdm import tqdm
from astropy.stats import sigma_clip
import os

ROOT_PATH = "/kaggle/input/ariel-data-challenge-2025"
MODE = "test"
import pandas as pd
import numpy as np
from astropy.stats import sigma_clip
import itertools

class Config:
    DATA_PATH = '/kaggle/input/ariel-data-challenge-2025'
    DATASET = "test"

    CUT_INF = 39
    CUT_SUP = 250

    SENSOR_CONFIG = {
        "AIRS-CH0": {
            "raw_shape": [11250, 32, 356],
            "calibrated_shape": [1, 32, CUT_SUP - CUT_INF],
            "linear_corr_shape": (6, 32, 356),
            "dt_pattern": (0.1, 4.5),
            "binning": 30
        },
        "FGS1": {
            "raw_shape": [135000, 32, 32],
            "calibrated_shape": [1, 32, 32],
            "linear_corr_shape": (6, 32, 32),
            "dt_pattern": (0.1, 0.1),
            "binning": 30 * 12
        }
    }


class SignalProcessor:
    def __init__(self, config):
        self.cfg = config
        self.planet_ids = pd.read_csv(f"{self.cfg.DATA_PATH}/{self.cfg.DATASET}_star_info.csv", index_col='planet_id').index.astype(int)

    def _calibrate_single_signal(self, planet_id, sensor):
        cfg = self.cfg.SENSOR_CONFIG[sensor]
        path = f"{self.cfg.DATA_PATH}/{self.cfg.DATASET}/{planet_id}/"

        signal = pd.read_parquet(path + f"{sensor}_signal_0.parquet").to_numpy().reshape(cfg["raw_shape"])
        dark = pd.read_parquet(path + f"{sensor}_calibration_0/dark.parquet").to_numpy()
        dead = pd.read_parquet(path + f"{sensor}_calibration_0/dead.parquet").to_numpy()
        flat = pd.read_parquet(path + f"{sensor}_calibration_0/flat.parquet").to_numpy()
        linear_corr = pd.read_parquet(path + f"{sensor}_calibration_0/linear_corr.parquet").to_numpy().astype(np.float64).reshape(cfg["linear_corr_shape"])

        gain, offset = 0.4369, -1000.0
        signal = signal / gain + offset

        hot = sigma_clip(dark, sigma=5, maxiters=5).mask

        if sensor == "AIRS-CH0":
            inf = self.cfg.CUT_INF
            sup = self.cfg.CUT_SUP
            signal = signal[:, :, inf:sup]
            linear_corr = linear_corr[:, :, inf:sup]
            dark = dark[:, inf:sup]
            dead = dead[:, inf:sup]
            flat = flat[:, inf:sup]
            hot = hot[:, inf:sup]

        base_dt, increment = cfg["dt_pattern"]
        dt = np.ones(len(signal)) * base_dt
        dt[1::2] += increment

        signal = signal.clip(0)
        linear_corr_flipped = np.flip(linear_corr, axis=0)
        corrected_signal = signal.copy()
        
        for x, y in itertools.product(range(signal.shape[1]), range(signal.shape[2])):
            poly = np.poly1d(linear_corr_flipped[:, x, y])
            corrected_signal[:, x, y] = poly(corrected_signal[:, x, y])
        signal = corrected_signal
        signal -= dark * dt[:, np.newaxis, np.newaxis]

        flat = flat.reshape(cfg["calibrated_shape"])
        dead_mask = dead.reshape(cfg["calibrated_shape"])
        hot_mask = hot.reshape(cfg["calibrated_shape"])

        flat[dead_mask] = np.nan
        flat[hot_mask] = np.nan

        signal = signal / flat

        return signal

    def _preprocess_calibrated_signal(self, signal, sensor):
        cfg = self.cfg.SENSOR_CONFIG[sensor]
        binning = cfg["binning"]

        if sensor == "AIRS-CH0":
            roi = signal[:, 10:22, :]
        else:
            roi = signal[:, 10:22, 10:22]
            roi = roi.reshape(roi.shape[0], -1)

        mean_signal = np.nanmean(roi, axis=1)
        
        cds_signal = mean_signal[1::2] - mean_signal[0::2]

        n_bins = cds_signal.shape[0] // binning
        binned = np.array([
            cds_signal[j*binning : (j+1)*binning].mean(axis=0) 
            for j in range(n_bins)
        ])

        if sensor == "FGS1":
            binned = binned.reshape((binned.shape[0], 1))
        return binned


    def process_all_data(self):
        combined_signals = []
    
        for planet_id in tqdm(self.planet_ids):
            signal_fgs = self._calibrate_single_signal(planet_id, "FGS1")
            processed_fgs = self._preprocess_calibrated_signal(signal_fgs, "FGS1")
    
            signal_airs = self._calibrate_single_signal(planet_id, "AIRS-CH0")
            processed_airs = self._preprocess_calibrated_signal(signal_airs, "AIRS-CH0")
    
            combined = np.concatenate([processed_fgs, processed_airs], axis=1)
            combined_signals.append(combined)
    
        result = np.stack(combined_signals)
        return result

# %%
processor = SignalProcessor(Config)
StarInfo = pd.read_csv(ROOT_PATH + f"/{MODE}_star_info.csv")
StarInfo["planet_id"] = StarInfo["planet_id"].astype(int)
PlanetIds = StarInfo["planet_id"].tolist()
StarInfo = StarInfo.set_index("planet_id")
signal_train = processor.process_all_data()
# Out:
# 100%|██████████| 1/1 [00:25<00:00, 25.34s/it]

# %%
signal_train.shape
# Out:
# (1, 187, 212)

# %%
signal_train
# Out:
# array([[[1856.11880177,  326.26039964,  353.85240296, ...,
#          4981.90413106, 5020.88653908, 5093.33476187],
#         [1856.44250718,  320.96252327,  355.36135578, ...,
#          4974.16337172, 5015.00256043, 5089.93390507],
#         [1856.11326716,  320.82204194,  353.7942714 , ...,
#          4986.14792999, 5019.63113969, 5096.09717766],
#         ...,
#         [1855.21181766,  323.47909872,  353.47364805, ...,
#          4982.52174934, 5016.71581369, 5090.31061791],
#         [1855.55615027,  321.06873983,  354.27098624, ...,
#          4975.9851108 , 5024.09122061, 5093.95996765],
#         [1855.44050101,  325.19038634,  353.75441626, ...,
#          4974.42244434, 5016.07635492, 5095.15754892]]])

# %%
from scipy.signal import savgol_filter
def phase_detector(signal):
    min_index = np.argmin(signal[30:140]) + 30
    signal1 = signal[:min_index]
    grad1 = np.gradient(signal1)
    grad1 /= grad1.max()
    signal2 = signal[min_index:]
    grad2 = np.gradient(signal2)
    grad2 /= grad2.max()

    phase1 = np.argmin(grad1)
    phase2 = np.argmax(grad2) + min_index

    return phase1, phase2

# %%
from scipy.optimize import minimize
import numpy as np
import numpy as np
from scipy.optimize import minimize

def compute_s_opt(signal, phase1, phase2, buffer_size = 7, degree = 3):
    delta = buffer_size
    if phase1 - delta <= 0 or phase2 + delta >= len(signal) or phase2 - delta - (phase1 + delta) < 5:
        delta = 2
    def objective(s):
        middle = signal[phase1 + delta : phase2 - delta] * (1 + s)
        y = np.concatenate([signal[:phase1 - delta], middle, signal[phase2 + delta:]])
        x = np.arange(len(y))
        coeffs = np.polyfit(x, y, degree)
        poly = np.poly1d(coeffs)        
        return np.abs(poly(x) - y).mean()

    res = minimize(objective, 0.0001, method="Nelder-Mead")
    return res.x[0]

# %%
y_shifts = []

for IDX in tqdm(range(len(signal_train))):
    data = signal_train[IDX]
    normalized_data = data[:, 1:].mean(1)
    normalized_data = savgol_filter(normalized_data, 30, 2)
    phase1, phase2 = phase_detector(normalized_data)
    buffer_size_poly = 7
    phase1 = max(7, phase1)
    phase2 = min(len(normalized_data) - 7 - 1, phase2) 
    _ = compute_s_opt(normalized_data, phase1, phase2, buffer_size_poly, degree = 3)
    print(_)
    y_shifts.append(_)
y_shifts = np.array(y_shifts) * 0.93960
df = pd.DataFrame({"transit_depth":y_shifts},index=StarInfo.index,)
#input_df = pd.merge(df, StarInfo, on="planet_id", how="left")
y_shifts
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 11.19it/s]
# 0.016935000000000033
# array([0.01591213])

# %%
input_df = pd.merge(df, StarInfo, on="planet_id", how="left")
input_df
# Out:
#            transit_depth        Rs      Ms          Ts        Mp    e  \
# planet_id
# 1103775         0.015912  0.965432  0.9591  5539.03037  1.665007  0.0
#
#                   P       sma          i
# planet_id
# 1103775    6.932871  15.43293  89.533139

# %%
input_df["transit_depth"] *= 10000
features = ['transit_depth','Rs','i']
X = input_df[features].values.astype(np.float32)
X
# Out:
# array([[159.12126 ,   0.965432,  89.53314 ]], dtype=float32)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
class ResidualBlock(nn.Module):
    def __init__(self, dim, p=0.2):
        super().__init__()
        self.fc1 = nn.Linear(dim, dim)
        self.bn1 = nn.BatchNorm1d(dim)
        self.fc2 = nn.Linear(dim, dim)
        self.bn2 = nn.BatchNorm1d(dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p)

    def forward(self, x):
        identity = x
        out = self.relu(self.bn1(self.fc1(x)))
        out = self.dropout(out)
        out = self.bn2(self.fc2(out))
        return self.relu(out + identity)


class ResNetMLP(nn.Module):
    def __init__(self, input_dim=3, hidden_dim=32, output_dim=1, num_blocks=3, dropout_rate=0.2):
        super().__init__()
        self.input_layer = nn.Linear(input_dim, hidden_dim)
        self.blocks = nn.Sequential(*[ResidualBlock(hidden_dim, p=dropout_rate) for _ in range(num_blocks)])
        self.output_layer = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.input_layer(x)
        x = self.blocks(x)
        x = self.output_layer(x)
        return x

# %%
model = ResNetMLP(num_blocks=80, dropout_rate=0.3)
model.load_state_dict(torch.load("/kaggle/input/net/pytorch/default/1/best_artifacts/best_model.pth"))
model.eval()
# Out:
# ResNetMLP(
#   (input_layer): Linear(in_features=3, out_features=32, bias=True)
#   (blocks): Sequential(
#     (0): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (1): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (2): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (3): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (4): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (5): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (6): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (7): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (8): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (9): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (10): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (11): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (12): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (13): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (14): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (15): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (16): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (17): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (18): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (19): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (20): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (21): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (22): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (23): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (24): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (25): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (26): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (27): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (28): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (29): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (30): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (31): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (32): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (33): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (34): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (35): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (36): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (37): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (38): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (39): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (40): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (41): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (42): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (43): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (44): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (45): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (46): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (47): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (48): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (49): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (50): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (51): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (52): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (53): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (54): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (55): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (56): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (57): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (58): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (59): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (60): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (61): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (62): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (63): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (64): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (65): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (66): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (67): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (68): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (69): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (70): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (71): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (72): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (73): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (74): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (75): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (76): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (77): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (78): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (79): ResidualBlock(
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (output_layer): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
X_tensor = torch.tensor(X, dtype=torch.float32)
with torch.no_grad():
    y_pred = model(X_tensor).numpy()

y_pred /= 10000
y_pred
# Out:
# array([[0.01533113]], dtype=float32)

# %%
X
# Out:
# array([[159.12126 ,   0.965432,  89.53314 ]], dtype=float32)

# %%
# Đọc sample
sample = pd.read_csv("/kaggle/input/ariel-data-challenge-2025/sample_submission.csv")

# Bỏ cột planet_id (vì chỉ dùng làm index chứ không dùng làm column)
sample_columns = sample.columns.drop("planet_id")

# Lặp prediction cho đủ chiều
n_outputs = len(sample_columns) // 2  # 283
repeated_predictions = np.repeat(df.values, n_outputs).reshape(len(df), -1)
repeated_predictions[:,0] = (y_pred[:,0] * 0.4 + (X[:,0] * 0.6 )/ 10000)
repeated_predictions = repeated_predictions.clip(0)

# Tạo sigma
sigmas = np.ones_like(repeated_predictions) * 0.0009

# Gộp lại
submission_values = np.concatenate([repeated_predictions, sigmas], axis=1)

# Tạo submission_df
submission_df = pd.DataFrame(submission_values, columns=sample_columns, index=df.index)

# Thêm lại cột planet_id vào đầu (trùng với index)
submission_df.insert(0, "planet_id", df.index)

# Ghi file
submission_df.to_csv("submission.csv", index=False)

# %%
pd.read_csv("submission.csv")
# Out:
#    planet_id     wl_1      wl_2      wl_3      wl_4      wl_5      wl_6  \
# 0    1103775  0.01568  0.015912  0.015912  0.015912  0.015912  0.015912
#
#        wl_7      wl_8      wl_9  ...  sigma_274  sigma_275  sigma_276  \
# 0  0.015912  0.015912  0.015912  ...     0.0009     0.0009     0.0009
#
#    sigma_277  sigma_278  sigma_279  sigma_280  sigma_281  sigma_282  sigma_283
# 0     0.0009     0.0009     0.0009     0.0009     0.0009     0.0009     0.0009
#
# [1 rows x 567 columns]
